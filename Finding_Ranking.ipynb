# %%
! pip install psycopg2 sqlalchemy
# Out:
# Collecting psycopg2
#   Downloading psycopg2-2.9.10-cp312-cp312-win_amd64.whl.metadata (5.0 kB)
# Requirement already satisfied: sqlalchemy in c:\users\dina_\anaconda3\lib\site-packages (2.0.30)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\dina_\anaconda3\lib\site-packages (from sqlalchemy) (4.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\dina_\anaconda3\lib\site-packages (from sqlalchemy) (3.0.1)
# Downloading psycopg2-2.9.10-cp312-cp312-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    - -------------------------------------- 0.0/1.2 MB 435.7 kB/s eta 0:00:03
#    ---- ----------------------------------- 0.1/1.2 MB 1.4 MB/s eta 0:00:01
#    ------------------------------------ --- 1.1/1.2 MB 6.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 7.4 MB/s eta 0:00:00
# Installing collected packages: psycopg2
# Successfully installed psycopg2-2.9.10

# %%
from sqlalchemy import create_engine
import pandas as pd
from datetime import datetime
SQLALCHEMY_DATABASE_URL = "postgresql://db_root:Mumbai2020#@localhost:5432/postgres"

engine = create_engine(SQLALCHEMY_DATABASE_URL)

query = """
select f.flaw_id, f.title, count(distinct al.asset_id) from findings f, asset_findingmap af, asset_list al, finding_cvemap fc, clientslist c where f.client_id = c.client_id and al.client_id = c.client_id and af.client_id = c.client_id and al.asset_id = af.asset_id and af.findings_id = f.flaw_id and fc.flaw_id = f.flaw_id and fc.report_id = f.report_id and af.asset_id = al.asset_id and f.status = "Open" and f.severity = "Critical" and al."assetCriticality" = "Critical"  group by f.flaw_id, f.title order by count(distinct al.asset_id)  desc limit 10
"""

df_findings = pd.read_sql(query_findings, engine)

df_findings['last_update'] = pd.to_datetime(df_findings['last_update'])

preset_date = datetime(2024, 8, 14)

df_findings['days_since_last_update'] = (preset_date - df_findings['last_update']).dt.days

print(df_findings)
# Out:
#         flaw_id             last_update  severity assetCriticality  \
# 0         90150 2024-02-08 16:24:51.497  Critical         Critical
# 1         90150 2024-02-08 16:24:51.497  Critical         Critical
# 2         90150 2024-02-08 16:24:51.497  Critical         Critical
# 3         90150 2024-02-08 16:24:51.497  Critical         Critical
# 4         90150 2024-02-08 16:24:51.497  Critical         Critical
# ...         ...                     ...       ...              ...
# 528760    11356 2024-06-19 14:10:56.101  Critical         Critical
# 528761    11356 2024-06-19 14:10:56.101  Critical         Critical
# 528762    11356 2024-06-19 14:10:56.101  Critical         Critical
# 528763    11356 2024-06-19 14:10:56.101  Critical         Critical
# 528764    11356 2024-06-19 14:10:56.101  Critical         Critical
#
#         days_since_last_update
# 0                          187
# 1                          187
# 2                          187
# 3                          187
# 4                          187
# ...                        ...
# 528760                      55
# 528761                      55
# 528762                      55
# 528763                      55
# 528764                      55
#
# [528765 rows x 5 columns]

# %%
intel_df['patch_available'] = pd.to_datetime(intel_df['patch_available'], errors='coerce')

intel_df['patch_age_score'] = intel_df['patch_available'].apply(calculate_patch_age_score)

# %%
def determine_priority(row):
    exploit_ease = row['exploit_ease']
    exploit_available = row['exploit_available']
    risk_factor = row['risk_factor']
    score = row['score']
    score_decimal = score - int(score)

    if exploit_ease == False and exploit_available == False:
        return 1
    elif exploit_ease == True and exploit_available == True:
        if risk_factor == 'Critical':
            return 4 + float(score_decimal)
        elif risk_factor == 'High':
            return 3 + float(score_decimal)
        elif risk_factor == 'Medium':
            return 2 + float(score_decimal)
        elif risk_factor == 'Low':
            return 1 + float(score_decimal)

# %%
intel_df['Flaw_Score'] = intel_df.apply(determine_priority, axis=1)

# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine('postgresql://db_root:Mumbai2020#@localhost:5432/postgres')

def get_ease_of_remediation(flaw_id):
    query = f"""
    SELECT status FROM plextrac_findings WHERE flaw_id = '{flaw_id}';
    """
    results = pd.read_sql(query, engine)
    
    if 'Closed' in results['status'].values:
        return 3
    elif 'In Process' in results['status'].values:
        return 2
    else:
        return 1

intel_df['ease_of_remediation'] = intel_df['flaw_id'].apply(get_ease_of_remediation)

# %%
weights = {
    'Prevalence_Score': 0.6,
    'cve_score': 0.75,
    'Flaw_Score': 0.6,
    'ease_of_remediation': 0.4,
    'patch_age_score': 0.4
}

intel_df['total_score'] = (
    intel_df['Prevalence_Score'] * weights['Prevalence_Score'] +
    intel_df['cve_score'] * weights['cve_score'] +
    intel_df['Flaw_Score'] * weights['Flaw_Score'] +
    intel_df['ease_of_remediation'] * weights['ease_of_remediation'] +
    intel_df['patch_age_score'] * weights['patch_age_score']
)

# %%
df_sorted = intel_df.sort_values(by='total_score', ascending=False)

columns_to_show = ['flaw_id', 'risk_factor', 'score', 'exploit_ease', 'exploit_available', 'cve_score', 'patch_available', 'total_score']
df_filtered = df_sorted[columns_to_show]

# %%
import pandas as pd

file_path = 'C:/Users/Kannan/Desktop/Databahn/ARM/asset_intel.xlsx'
df = pd.read_excel(file_path)

def calculate_total_score(row):
    if row['decommissioned'] == 0:
        criticality_weight = 0.75
        exposure_weight = 0.6
        risk_factors_weight = 0.5
    else:
        criticality_weight = 0.5
        exposure_weight = 0.25
        risk_factors_weight = 0.2

    total_score = (row['criticality'] * criticality_weight +
                   row['exposure'] * exposure_weight +
                   row['risk_factors'] * risk_factors_weight)
    return total_score

df['total_score'] = df.apply(calculate_total_score, axis=1)

output_path = 'asset_intel_results.xlsx'
df.to_excel(output_path, index=False)

# %%
import pandas as pd

file_path = 'C:/Users/Kannan/Desktop/Databahn/ARM/results.xlsx'

findings_rank = pd.read_excel(file_path, sheet_name='finding_rank')
assets_rank = pd.read_excel(file_path, sheet_name='asset_rank')

# %%
from sqlalchemy import create_engine

SQLALCHEMY_DATABASE_URL = "postgresql://db_root:Mumbai2020#@localhost:5432/postgres"
engine = create_engine(SQLALCHEMY_DATABASE_URL)

# %%
def fetch_asset_ids_for_flaw(flaw_id, engine):
    query = f"""
    SELECT 
        f.flaw_id, 
        f.title, 
        COUNT(DISTINCT al.asset_id), 
        STRING_AGG(DISTINCT al.asset_id::text, ', ') AS asset_ids
    FROM 
        plextrac_findings f
    JOIN 
        plextrac_asset_finding_map af ON af.findings_id = f.flaw_id
    JOIN 
        plextrac_asset_list al ON al.client_id = f.client_id AND af.asset_id = al.asset_id
    JOIN 
        plextrac_finding_cve_map fc ON fc.flaw_id = f.flaw_id AND fc.report_id = f.report_id
    JOIN 
        plextrac_clients_list cl ON f.client_id = cl.client_id
    WHERE 
        f.flaw_id = '{flaw_id}' AND 
        f.status = 'Open'
    GROUP BY 
        f.flaw_id, f.title
    ORDER BY 
        COUNT(DISTINCT al.asset_id) DESC 
    """
    result = pd.read_sql(query, engine)
    return result

for idx, row in findings_rank.iterrows():
    flaw_id = row['flaw_id']
    asset_ids_result = fetch_asset_ids_for_flaw(flaw_id, engine)
    
    if not asset_ids_result.empty:
        findings_rank.at[idx, 'asset_ids'] = asset_ids_result['asset_ids'].iloc[0]

# %%
expanded_findings_rank = findings_rank.assign(asset_id=findings_rank['asset_ids'].str.split(', ')).explode('asset_id')

assets_rank = assets_rank.rename(columns={'total_score': 'asset_total_score'})

merged_df = pd.merge(expanded_findings_rank, assets_rank, how='left', on='asset_id')

selected_columns = [
    'flaw_id', 'asset_id', 'risk_factor', 'total_score', 'exploit_ease', 'asset_total_score',
    'exploit_available', 'patch_available', 'prevalence', 'no_of_cve', 
    'ease_of_remediation', 'criticality', 'exposure', 'risk_factors', 
    'decommissioned'
]

merged_df['total_score'] = merged_df.apply(
    lambda row: row['total_score'] + 0.75 * row['asset_total_score'] if pd.notna(row['asset_total_score']) else row['total_score'],
    axis=1
)

output_df = merged_df[selected_columns]

output_df_sorted = output_df.sort_values(by='total_score', ascending=False)

print(output_df_sorted)

output_df_sorted.to_excel('output_sorted_findings_and_assets_expanded_with_adjusted_scores.xlsx', index=False)
# Out:
#        flaw_id                              asset_id risk_factor  total_score  \
# 144     190482  ea9e175b-2dc4-4631-ad61-79e817e7eed1    Critical       12.215
# 80      190482  85ccaba2-cd09-486c-a4f6-a86e0feab8ad    Critical       12.215
# 262     202028  85ccaba2-cd09-486c-a4f6-a86e0feab8ad    Critical       12.165
# 455     197006  85ccaba2-cd09-486c-a4f6-a86e0feab8ad    Critical       12.095
# 117     190482  c4a300f8-9798-4a87-b82b-5f6826031fb3    Critical       11.765
# ...        ...                                   ...         ...          ...
# 78516    31705  3569e2a3-91a6-420d-bbac-4088a7f5f7fb      Medium        2.350
# 78515    31705  352d5d37-7f19-466b-bd9a-8c453cc5a7f8      Medium        2.350
# 78514    31705  3203fd6a-9d2f-45ec-b9f9-4fee33b8cacf      Medium        2.350
# 78513    31705  315ff214-a27e-4df2-8f3f-d67a2dbd56ef      Medium        2.350
# 78583    31705  fcdd9302-b38b-4ad7-b19c-0250288a90a6      Medium        2.350
#
#        exploit_ease  asset_total_score  exploit_available  \
# 144            True                6.3               True
# 80             True                6.3               True
# 262            True                6.3               True
# 455            True                6.3               True
# 117            True                5.7               True
# ...             ...                ...                ...
# 78516         False                NaN              False
# 78515         False                NaN              False
# 78514         False                NaN              False
# 78513         False                NaN              False
# 78583         False                NaN              False
#
#            patch_available  prevalence  no_of_cve  ease_of_remediation  \
# 144             13-02-2024          73         39                    2
# 80              13-02-2024          73         39                    2
# 262    2024-07-09 00:00:00          83         79                    2
# 455             14-05-2024          82         44                    2
# 117             13-02-2024          73         39                    2
# ...                    ...         ...        ...                  ...
# 78516                  NaN          97          1                    1
# 78515                  NaN          97          1                    1
# 78514                  NaN          97          1                    1
# 78513                  NaN          97          1                    1
# 78583                  NaN          97          1                    1
#
#        criticality  exposure  risk_factors  decommissioned
# 144            4.0       3.0           3.0             0.0
# 80             4.0       3.0           3.0             0.0
# 262            4.0       3.0           3.0             0.0
# 455            4.0       3.0           3.0             0.0
# 117            4.0       2.0           3.0             0.0
# ...            ...       ...           ...             ...
# 78516          NaN       NaN           NaN             NaN
# 78515          NaN       NaN           NaN             NaN
# 78514          NaN       NaN           NaN             NaN
# 78513          NaN       NaN           NaN             NaN
# 78583          NaN       NaN           NaN             NaN
#
# [78584 rows x 15 columns]

# %%
def fetch_cve_for_flaw(flaw_id, engine):
    query = f"""
    SELECT STRING_AGG(DISTINCT cve::text, ', ') AS cves
    FROM plextrac_finding_cve_map 
    WHERE flaw_id = '{flaw_id}'; 
    """
    result = pd.read_sql(query, engine)
    return result

for idx, row in findings_rank.iterrows():
    flaw_id = row['flaw_id']
    cves = fetch_cve_for_flaw(flaw_id, engine)
    
    if not asset_ids_result.empty:
        findings_rank.at[idx, 'cves'] = cves['cves'].iloc[0]

# %%
file_path = 'C:/Users/Kannan/Desktop/Databahn/ARM/mandiant_vulns.csv'

mandiant_vulns = pd.read_csv(file_path)

# %%
mandiant_vulns
# Out:
#      sql_id  api_pg_num          cve_id  \
# 0       167           1  CVE-2024-42813
# 1       166           1  CVE-2024-23168
# 2       159           1   CVE-2024-6917
# 3       160           1  CVE-2024-38199
# 4       162           1  CVE-2024-38063
# ..      ...         ...             ...
# 129       4           1  CVE-2024-31996
# 130       5           1  CVE-2024-31982
# 131      14           1   CVE-2024-3098
# 132      15           1  CVE-2024-21508
# 133       8           1  CVE-2024-25912
#
#                                     file_name date_file  \
# 0    2024-08-21 063424 mandiant vuln list.csv   34:24.0
# 1    2024-08-17 063425 mandiant vuln list.csv   34:25.0
# 2    2024-08-14 063916 mandiant vuln list.csv   39:16.0
# 3    2024-08-14 063916 mandiant vuln list.csv   39:16.0
# 4    2024-08-14 063916 mandiant vuln list.csv   39:16.0
# ..                                        ...       ...
# 129  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 130  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 131  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 132  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 133  2024-04-12 093643 mandiant vuln list.csv   36:43.0
#
#                                            description  \
# 0    <p>Cybersecurity and Infrastructure Security A...
# 1    <p>Cybersecurity and Infrastructure Security A...
# 2    <p>Mitre Corporation has provided the followin...
# 3    <p>Mitre Corporation has provided the followin...
# 4    <p>Mitre Corporation has provided the followin...
# ..                                                 ...
# 129  <p>National Vulnerability Database has provide...
# 130  <p>National Vulnerability Database has provide...
# 131  <p>National Vulnerability Database has provide...
# 132  <p>National Vulnerability Database has provide...
# 133  <p>National Vulnerability Database has provide...
#
#                                                     id exploitation_state  \
# 0    vulnerability--3f73a573-108c-54d2-8898-9dd2ab1...          Available
# 1    vulnerability--ef6c6a14-e9d6-5fa4-b3a0-c5868b6...           No Known
# 2    vulnerability--1d18129c-78f5-5493-b762-7e88742...           No Known
# 3    vulnerability--2be556cf-6aff-5cf5-a5ed-c5dcb25...           No Known
# 4    vulnerability--0afe9d27-0aa8-55e7-b2f6-30914d0...           No Known
# ..                                                 ...                ...
# 129  vulnerability--17dd4259-bd44-55bc-a130-2bf8750...           No Known
# 130  vulnerability--a5f642b0-ef35-5182-acc0-73ee0f9...           No Known
# 131  vulnerability--fb4929a5-df98-52f9-95b2-ff85886...          Available
# 132  vulnerability--a02c3694-0043-519f-ab0b-e048a81...          Available
# 133  vulnerability--ee4bd262-f40b-5445-9bf6-61fe5e7...           No Known
#
#      intel_free  is_predicted  ...  remediation_level report_confidence  \
# 0         False         False  ...        NOT_DEFINED         CONFIRMED
# 1         False         False  ...       OFFICIAL_FIX         CONFIRMED
# 2         False         False  ...        NOT_DEFINED         CONFIRMED
# 3         False         False  ...       OFFICIAL_FIX         CONFIRMED
# 4         False         False  ...       OFFICIAL_FIX         CONFIRMED
# ..          ...           ...  ...                ...               ...
# 129       False         False  ...        NOT_DEFINED         CONFIRMED
# 130       False         False  ...        NOT_DEFINED         CONFIRMED
# 131       False         False  ...        NOT_DEFINED         CONFIRMED
# 132       False         False  ...        NOT_DEFINED         CONFIRMED
# 133       False         False  ...        NOT_DEFINED         CONFIRMED
#
#          scope  temporal_score  user_interaction  \
# 0    UNCHANGED             9.8              NONE
# 1    UNCHANGED             8.5              NONE
# 2    UNCHANGED             9.8              NONE
# 3    UNCHANGED             8.5              NONE
# 4    UNCHANGED             8.5              NONE
# ..         ...             ...               ...
# 129    CHANGED            10.0              NONE
# 130    CHANGED            10.0              NONE
# 131  UNCHANGED             9.8              NONE
# 132  UNCHANGED             9.8              NONE
# 133  UNCHANGED             9.8              NONE
#
#                                          vector_string access_complexity  \
# 0         CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 1    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H/E...               NaN
# 2         CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 3    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H/E...               NaN
# 4    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H/E...               NaN
# ..                                                 ...               ...
# 129       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:C/C:H/I:H/A:H               NaN
# 130       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:C/C:H/I:H/A:H               NaN
# 131       CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 132       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 133       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
#
#     access_vector  authentication exploitability
# 0             NaN             NaN            NaN
# 1             NaN             NaN            NaN
# 2             NaN             NaN            NaN
# 3             NaN             NaN            NaN
# 4             NaN             NaN            NaN
# ..            ...             ...            ...
# 129           NaN             NaN            NaN
# 130           NaN             NaN            NaN
# 131           NaN             NaN            NaN
# 132           NaN             NaN            NaN
# 133           NaN             NaN            NaN
#
# [134 rows x 33 columns]

# %%
mandiant_vulns['cve_total_score'] = 0

mandiant_vulns['cve_total_score'] += mandiant_vulns['exploitation_state'].apply(lambda x: 2 if x in ['Available', 'Confirmed'] else 0)

mandiant_vulns['cve_total_score'] += mandiant_vulns['observed_in_the_wild'].apply(lambda x: 2 if x else 0)

mandiant_vulns['cve_total_score'] += mandiant_vulns['base_score'].apply(lambda x: 4 if x > 9 else (3 if x >= 7 else (2 if x >= 4 else 1)))

print(mandiant_vulns)
# Out:
#      sql_id  api_pg_num          cve_id  \
# 0       167           1  CVE-2024-42813
# 1       166           1  CVE-2024-23168
# 2       159           1   CVE-2024-6917
# 3       160           1  CVE-2024-38199
# 4       162           1  CVE-2024-38063
# ..      ...         ...             ...
# 129       4           1  CVE-2024-31996
# 130       5           1  CVE-2024-31982
# 131      14           1   CVE-2024-3098
# 132      15           1  CVE-2024-21508
# 133       8           1  CVE-2024-25912
#
#                                     file_name date_file  \
# 0    2024-08-21 063424 mandiant vuln list.csv   34:24.0
# 1    2024-08-17 063425 mandiant vuln list.csv   34:25.0
# 2    2024-08-14 063916 mandiant vuln list.csv   39:16.0
# 3    2024-08-14 063916 mandiant vuln list.csv   39:16.0
# 4    2024-08-14 063916 mandiant vuln list.csv   39:16.0
# ..                                        ...       ...
# 129  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 130  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 131  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 132  2024-04-12 093643 mandiant vuln list.csv   36:43.0
# 133  2024-04-12 093643 mandiant vuln list.csv   36:43.0
#
#                                            description  \
# 0    <p>Cybersecurity and Infrastructure Security A...
# 1    <p>Cybersecurity and Infrastructure Security A...
# 2    <p>Mitre Corporation has provided the followin...
# 3    <p>Mitre Corporation has provided the followin...
# 4    <p>Mitre Corporation has provided the followin...
# ..                                                 ...
# 129  <p>National Vulnerability Database has provide...
# 130  <p>National Vulnerability Database has provide...
# 131  <p>National Vulnerability Database has provide...
# 132  <p>National Vulnerability Database has provide...
# 133  <p>National Vulnerability Database has provide...
#
#                                                     id exploitation_state  \
# 0    vulnerability--3f73a573-108c-54d2-8898-9dd2ab1...          Available
# 1    vulnerability--ef6c6a14-e9d6-5fa4-b3a0-c5868b6...           No Known
# 2    vulnerability--1d18129c-78f5-5493-b762-7e88742...           No Known
# 3    vulnerability--2be556cf-6aff-5cf5-a5ed-c5dcb25...           No Known
# 4    vulnerability--0afe9d27-0aa8-55e7-b2f6-30914d0...           No Known
# ..                                                 ...                ...
# 129  vulnerability--17dd4259-bd44-55bc-a130-2bf8750...           No Known
# 130  vulnerability--a5f642b0-ef35-5182-acc0-73ee0f9...           No Known
# 131  vulnerability--fb4929a5-df98-52f9-95b2-ff85886...          Available
# 132  vulnerability--a02c3694-0043-519f-ab0b-e048a81...          Available
# 133  vulnerability--ee4bd262-f40b-5445-9bf6-61fe5e7...           No Known
#
#      intel_free  is_predicted  ...  report_confidence      scope  \
# 0         False         False  ...          CONFIRMED  UNCHANGED
# 1         False         False  ...          CONFIRMED  UNCHANGED
# 2         False         False  ...          CONFIRMED  UNCHANGED
# 3         False         False  ...          CONFIRMED  UNCHANGED
# 4         False         False  ...          CONFIRMED  UNCHANGED
# ..          ...           ...  ...                ...        ...
# 129       False         False  ...          CONFIRMED    CHANGED
# 130       False         False  ...          CONFIRMED    CHANGED
# 131       False         False  ...          CONFIRMED  UNCHANGED
# 132       False         False  ...          CONFIRMED  UNCHANGED
# 133       False         False  ...          CONFIRMED  UNCHANGED
#
#     temporal_score  user_interaction  \
# 0              9.8              NONE
# 1              8.5              NONE
# 2              9.8              NONE
# 3              8.5              NONE
# 4              8.5              NONE
# ..             ...               ...
# 129           10.0              NONE
# 130           10.0              NONE
# 131            9.8              NONE
# 132            9.8              NONE
# 133            9.8              NONE
#
#                                          vector_string access_complexity  \
# 0         CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 1    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H/E...               NaN
# 2         CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 3    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H/E...               NaN
# 4    CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H/E...               NaN
# ..                                                 ...               ...
# 129       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:C/C:H/I:H/A:H               NaN
# 130       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:C/C:H/I:H/A:H               NaN
# 131       CVSS:3.0/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 132       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
# 133       CVSS:3.1/AV:N/AC:L/PR:N/UI:N/S:U/C:H/I:H/A:H               NaN
#
#     access_vector authentication  exploitability cve_total_score
# 0             NaN            NaN             NaN               6
# 1             NaN            NaN             NaN               4
# 2             NaN            NaN             NaN               4
# 3             NaN            NaN             NaN               4
# 4             NaN            NaN             NaN               4
# ..            ...            ...             ...             ...
# 129           NaN            NaN             NaN               4
# 130           NaN            NaN             NaN               4
# 131           NaN            NaN             NaN               6
# 132           NaN            NaN             NaN               6
# 133           NaN            NaN             NaN               4
#
# [134 rows x 34 columns]

# %%
findings_rank['cve_list'] = findings_rank['cves'].apply(lambda x: x.split(', '))

cve_flaw_pairs = findings_rank.explode('cve_list')

merged_df = cve_flaw_pairs.merge(mandiant_vulns, left_on='cve_list', right_on='cve_id', how='left')

merged_df
# Out:
#      flaw_id risk_factor  score  exploit_ease  exploit_available  \
# 0     190482    Critical    9.4          True               True
# 1     190482    Critical    9.4          True               True
# 2     190482    Critical    9.4          True               True
# 3     190482    Critical    9.4          True               True
# 4     190482    Critical    9.4          True               True
# ..       ...         ...    ...           ...                ...
# 413    42411      Medium    6.6         False              False
# 414    83875         Low    2.9         False              False
# 415    42411      Medium    6.6         False              False
# 416    42411      Medium    6.6         False              False
# 417    31705      Medium    4.4         False              False
#
#     patch_available  prevalence  no_of_cve  cve_score  Prevalence_Score  ...  \
# 0        13-02-2024          73         39          3                 1  ...
# 1        13-02-2024          73         39          3                 1  ...
# 2        13-02-2024          73         39          3                 1  ...
# 3        13-02-2024          73         39          3                 1  ...
# 4        13-02-2024          73         39          3                 1  ...
# ..              ...         ...        ...        ...               ...  ...
# 413             NaN         102          2          1                 2  ...
# 414             NaN         410          1          1                 2  ...
# 415             NaN          36          2          1                 1  ...
# 416             NaN          36          2          1                 1  ...
# 417             NaN          97          1          1                 1  ...
#
#      report_confidence  scope  temporal_score  user_interaction vector_string  \
# 0                  NaN    NaN             NaN               NaN           NaN
# 1                  NaN    NaN             NaN               NaN           NaN
# 2                  NaN    NaN             NaN               NaN           NaN
# 3                  NaN    NaN             NaN               NaN           NaN
# 4                  NaN    NaN             NaN               NaN           NaN
# ..                 ...    ...             ...               ...           ...
# 413                NaN    NaN             NaN               NaN           NaN
# 414                NaN    NaN             NaN               NaN           NaN
# 415                NaN    NaN             NaN               NaN           NaN
# 416                NaN    NaN             NaN               NaN           NaN
# 417                NaN    NaN             NaN               NaN           NaN
#
#     access_complexity access_vector  authentication  exploitability  \
# 0                 NaN           NaN             NaN             NaN
# 1                 NaN           NaN             NaN             NaN
# 2                 NaN           NaN             NaN             NaN
# 3                 NaN           NaN             NaN             NaN
# 4                 NaN           NaN             NaN             NaN
# ..                ...           ...             ...             ...
# 413               NaN           NaN             NaN             NaN
# 414               NaN           NaN             NaN             NaN
# 415               NaN           NaN             NaN             NaN
# 416               NaN           NaN             NaN             NaN
# 417               NaN           NaN             NaN             NaN
#
#     cve_total_score
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
# ..              ...
# 413             NaN
# 414             NaN
# 415             NaN
# 416             NaN
# 417             NaN
#
# [418 rows x 51 columns]

# %%
cve_scores = merged_df.groupby('flaw_id')['cve_total_score'].sum().reset_index()
cve_scores['adjusted_cve_score'] = cve_scores['cve_total_score'] * 1.5
cve_scores
# Out:
#     flaw_id  cve_total_score  adjusted_cve_score
# 0     10114              0.0                 0.0
# 1     11197              0.0                 0.0
# 2     19948              0.0                 0.0
# 3     31705              0.0                 0.0
# 4     35291              0.0                 0.0
# ..      ...              ...                 ...
# 59   197009             14.0                21.0
# 60   197296              6.0                 9.0
# 61   200349              4.0                 6.0
# 62   200464              6.0                 9.0
# 63   202028             22.0                33.0
#
# [64 rows x 3 columns]

# %%
findings_rank = findings_rank.merge(cve_scores[['flaw_id', 'adjusted_cve_score']], on='flaw_id', how='left')

findings_rank['total_score'] += 0.75 * findings_rank['adjusted_cve_score']

print(findings_rank[['flaw_id', 'total_score']])
# Out:
#     flaw_id  total_score
# 0    190482         7.49
# 1    202028        32.19
# 2    197006        23.12
# 3    197009        23.12
# 4    159490         7.29
# ..      ...          ...
# 61    11197         3.47
# 62    42411         3.35
# 63    83875         3.35
# 64    42411         2.75
# 65    31705         2.35
#
# [66 rows x 2 columns]

# %%
findings_rank
# Out:
#     flaw_id risk_factor  score  exploit_ease  exploit_available  \
# 0    190482    Critical    9.4          True               True
# 1    202028    Critical    9.4          True               True
# 2    197006    Critical    9.2          True               True
# 3    197009    Critical    9.2          True               True
# 4    159490      Medium    4.9          True               True
# ..      ...         ...    ...           ...                ...
# 61    11197      Medium    4.2          True               True
# 62    42411      Medium    6.6         False              False
# 63    83875         Low    2.9         False              False
# 64    42411      Medium    6.6         False              False
# 65    31705      Medium    4.4         False              False
#
#         patch_available  prevalence  no_of_cve  cve_score  Prevalence_Score  \
# 0            13-02-2024          73         39          3                 1
# 1   2024-07-09 00:00:00          83         79          4                 1
# 2            14-05-2024          82         44          3                 1
# 3            14-05-2024          33         29          3                 1
# 4            24-08-2018        1042          1          1                 4
# ..                  ...         ...        ...        ...               ...
# 61                  NaN          76          1          1                 1
# 62                  NaN         102          2          1                 2
# 63                  NaN         410          1          1                 2
# 64                  NaN          36          2          1                 1
# 65                  NaN          97          1          1                 1
#
#     patch_age_score  Flaw_Score  ease_of_remediation  total_score  \
# 0                 3         4.4                    2         7.49
# 1                 1         4.4                    2        32.19
# 2                 3         4.2                    2        23.12
# 3                 3         4.2                    2        23.12
# 4                 3         2.9                    3         7.29
# ..              ...         ...                  ...          ...
# 61                0         2.2                    2         3.47
# 62                0         1.0                    2         3.35
# 63                0         1.0                    2         3.35
# 64                0         1.0                    2         2.75
# 65                0         1.0                    1         2.35
#
#                                             asset_ids  \
# 0   005f7cae-e8b4-4fba-8e73-f6cad1050f89, 03983413...
# 1   005f7cae-e8b4-4fba-8e73-f6cad1050f89, 03983413...
# 2   005f7cae-e8b4-4fba-8e73-f6cad1050f89, 03983413...
# 3   03513f1c-59e5-44d7-96a0-0ce79b2a89c5, 07ce1b39...
# 4   001ab0ed-9b64-4285-9c09-1291145cdfa4, 004dbeac...
# ..                                                ...
# 61  039fce7d-4e5f-45f5-be2f-779b914fc9e0, 0453511c...
# 62  00c54506-b83f-44a7-a434-bba62c5302b1, 012a84c6...
# 63  00114d58-41f3-4fbc-8408-1c0ca880d4ac, 0027ab94...
# 64  00c54506-b83f-44a7-a434-bba62c5302b1, 012a84c6...
# 65  02fa9c52-8894-489d-b3c1-459ab8f521e0, 0387cb25...
#
#                                                  cves  \
# 0   CVE-2023-50387, CVE-2024-21304, CVE-2024-21338...
# 1   CVE-2024-21417, CVE-2024-28899, CVE-2024-30013...
# 2   CVE-2024-29994, CVE-2024-29996, CVE-2024-29997...
# 3   CVE-2024-29996, CVE-2024-30006, CVE-2024-30008...
# 4                                      CVE-2018-15473
# ..                                                ...
# 61                                      CVE-2003-0001
# 62                       CVE-1999-0519, CVE-1999-0520
# 63                                      CVE-2015-4000
# 64                       CVE-1999-0519, CVE-1999-0520
# 65                                      CVE-2007-1858
#
#                                              cve_list  adjusted_cve_score
# 0   [CVE-2023-50387, CVE-2024-21304, CVE-2024-2133...                 0.0
# 1   [CVE-2024-21417, CVE-2024-28899, CVE-2024-3001...                33.0
# 2   [CVE-2024-29994, CVE-2024-29996, CVE-2024-2999...                21.0
# 3   [CVE-2024-29996, CVE-2024-30006, CVE-2024-3000...                21.0
# 4                                    [CVE-2018-15473]                 0.0
# ..                                                ...                 ...
# 61                                    [CVE-2003-0001]                 0.0
# 62                     [CVE-1999-0519, CVE-1999-0520]                 0.0
# 63                                    [CVE-2015-4000]                 0.0
# 64                     [CVE-1999-0519, CVE-1999-0520]                 0.0
# 65                                    [CVE-2007-1858]                 0.0
#
# [66 rows x 18 columns]

# %%
findings_df_sorted = findings_rank.sort_values(by='total_score', ascending=False)

print(findings_df_sorted)
# Out:
#     flaw_id risk_factor  score  exploit_ease  exploit_available  \
# 1    202028    Critical    9.4          True               True
# 2    197006    Critical    9.2          True               True
# 3    197009    Critical    9.2          True               True
# 9    197296    Critical    9.2          True               True
# 16   200464    Critical    9.5          True               True
# ..      ...         ...    ...           ...                ...
# 61    11197      Medium    4.2          True               True
# 62    42411      Medium    6.6         False              False
# 63    83875         Low    2.9         False              False
# 64    42411      Medium    6.6         False              False
# 65    31705      Medium    4.4         False              False
#
#         patch_available  prevalence  no_of_cve  cve_score  Prevalence_Score  \
# 1   2024-07-09 00:00:00          83         79          4                 1
# 2            14-05-2024          82         44          3                 1
# 3            14-05-2024          33         29          3                 1
# 9            14-05-2024         108          4          1                 2
# 16  2024-06-06 00:00:00          21          1          1                 1
# ..                  ...         ...        ...        ...               ...
# 61                  NaN          76          1          1                 1
# 62                  NaN         102          2          1                 2
# 63                  NaN         410          1          1                 2
# 64                  NaN          36          2          1                 1
# 65                  NaN          97          1          1                 1
#
#     patch_age_score  Flaw_Score  ease_of_remediation  total_score  \
# 1                 1         4.4                    2        32.19
# 2                 3         4.2                    2        23.12
# 3                 3         4.2                    2        23.12
# 9                 3         4.2                    2        13.22
# 16                3         4.5                    2        12.80
# ..              ...         ...                  ...          ...
# 61                0         2.2                    2         3.47
# 62                0         1.0                    2         3.35
# 63                0         1.0                    2         3.35
# 64                0         1.0                    2         2.75
# 65                0         1.0                    1         2.35
#
#                                             asset_ids  \
# 1   005f7cae-e8b4-4fba-8e73-f6cad1050f89, 03983413...
# 2   005f7cae-e8b4-4fba-8e73-f6cad1050f89, 03983413...
# 3   03513f1c-59e5-44d7-96a0-0ce79b2a89c5, 07ce1b39...
# 9   0287a0c7-b0a7-4c32-9c2a-0414848863d1, 0620d88e...
# 16  031fdab5-212a-4588-ba6a-e5a52449282d, 16610442...
# ..                                                ...
# 61  039fce7d-4e5f-45f5-be2f-779b914fc9e0, 0453511c...
# 62  00c54506-b83f-44a7-a434-bba62c5302b1, 012a84c6...
# 63  00114d58-41f3-4fbc-8408-1c0ca880d4ac, 0027ab94...
# 64  00c54506-b83f-44a7-a434-bba62c5302b1, 012a84c6...
# 65  02fa9c52-8894-489d-b3c1-459ab8f521e0, 0387cb25...
#
#                                                  cves  \
# 1   CVE-2024-21417, CVE-2024-28899, CVE-2024-30013...
# 2   CVE-2024-29994, CVE-2024-29996, CVE-2024-29997...
# 3   CVE-2024-29996, CVE-2024-30006, CVE-2024-30008...
# 9   CVE-2024-30045, CVE-2024-30046, CVE-2024-32002...
# 16                                      CVE-2024-4577
# ..                                                ...
# 61                                      CVE-2003-0001
# 62                       CVE-1999-0519, CVE-1999-0520
# 63                                      CVE-2015-4000
# 64                       CVE-1999-0519, CVE-1999-0520
# 65                                      CVE-2007-1858
#
#                                              cve_list  adjusted_cve_score
# 1   [CVE-2024-21417, CVE-2024-28899, CVE-2024-3001...                33.0
# 2   [CVE-2024-29994, CVE-2024-29996, CVE-2024-2999...                21.0
# 3   [CVE-2024-29996, CVE-2024-30006, CVE-2024-3000...                21.0
# 9   [CVE-2024-30045, CVE-2024-30046, CVE-2024-3200...                 9.0
# 16                                    [CVE-2024-4577]                 9.0
# ..                                                ...                 ...
# 61                                    [CVE-2003-0001]                 0.0
# 62                     [CVE-1999-0519, CVE-1999-0520]                 0.0
# 63                                    [CVE-2015-4000]                 0.0
# 64                     [CVE-1999-0519, CVE-1999-0520]                 0.0
# 65                                    [CVE-2007-1858]                 0.0
#
# [66 rows x 18 columns]

# %%
findings_df_sorted = findings_rank.sort_values(by='total_score', ascending=False)

findings_df_sorted = findings_df_sorted.drop(columns=['asset_ids', 'cves'])

findings_df_sorted.to_csv('sorted_findings.csv', index=False)

print(findings_df_sorted)
# Out:
#     flaw_id risk_factor  score  exploit_ease  exploit_available  \
# 1    202028    Critical    9.4          True               True
# 2    197006    Critical    9.2          True               True
# 3    197009    Critical    9.2          True               True
# 9    197296    Critical    9.2          True               True
# 16   200464    Critical    9.5          True               True
# ..      ...         ...    ...           ...                ...
# 61    11197      Medium    4.2          True               True
# 62    42411      Medium    6.6         False              False
# 63    83875         Low    2.9         False              False
# 64    42411      Medium    6.6         False              False
# 65    31705      Medium    4.4         False              False
#
#         patch_available  prevalence  no_of_cve  cve_score  Prevalence_Score  \
# 1   2024-07-09 00:00:00          83         79          4                 1
# 2            14-05-2024          82         44          3                 1
# 3            14-05-2024          33         29          3                 1
# 9            14-05-2024         108          4          1                 2
# 16  2024-06-06 00:00:00          21          1          1                 1
# ..                  ...         ...        ...        ...               ...
# 61                  NaN          76          1          1                 1
# 62                  NaN         102          2          1                 2
# 63                  NaN         410          1          1                 2
# 64                  NaN          36          2          1                 1
# 65                  NaN          97          1          1                 1
#
#     patch_age_score  Flaw_Score  ease_of_remediation  total_score  \
# 1                 1         4.4                    2        32.19
# 2                 3         4.2                    2        23.12
# 3                 3         4.2                    2        23.12
# 9                 3         4.2                    2        13.22
# 16                3         4.5                    2        12.80
# ..              ...         ...                  ...          ...
# 61                0         2.2                    2         3.47
# 62                0         1.0                    2         3.35
# 63                0         1.0                    2         3.35
# 64                0         1.0                    2         2.75
# 65                0         1.0                    1         2.35
#
#                                              cve_list  adjusted_cve_score
# 1   [CVE-2024-21417, CVE-2024-28899, CVE-2024-3001...                33.0
# 2   [CVE-2024-29994, CVE-2024-29996, CVE-2024-2999...                21.0
# 3   [CVE-2024-29996, CVE-2024-30006, CVE-2024-3000...                21.0
# 9   [CVE-2024-30045, CVE-2024-30046, CVE-2024-3200...                 9.0
# 16                                    [CVE-2024-4577]                 9.0
# ..                                                ...                 ...
# 61                                    [CVE-2003-0001]                 0.0
# 62                     [CVE-1999-0519, CVE-1999-0520]                 0.0
# 63                                    [CVE-2015-4000]                 0.0
# 64                     [CVE-1999-0519, CVE-1999-0520]                 0.0
# 65                                    [CVE-2007-1858]                 0.0
#
# [66 rows x 16 columns]
